# %% [markdown]
# # Assignment - 1
# **Q1. Student Information**
#
# Create variables for a student's name, age, city, and student status. Print all the
# information in a properly formatted output.

# %%
student_name='Huzaifa Tariq'
age= 23
city='Karachi'
is_student = True

# %%
print(f'Student Name: {student_name}')
print(f'Age: {age}')
print(f'City: {city}')
print(f'Student Status: {is_student}')
# Out:
# Student Name: Huzaifa Tariq
# Age: 23
# City: Karachi
# Student Status: True

# %% [markdown]
# **Q2.Data Types**
#
# Create variables containing a string, integer, float, and boolean. Print the value and data
# type of each variable using type().

# %%
var_string='huzaifa'
var_float=50.75
var_integer=2
var_boolean=True

# %%
print(f'{var_string} is a String value and data type is {type(var_string)}')  
print(f'{var_float} is a Float Value and data type is {type(var_float)}')  
print(f'{var_integer} is a integer Value and data type is {type(var_integer)}') 
print(f'{var_boolean} is a boolean Value and data type is {type(var_boolean)}')
# Out:
# huzaifa is a String value and data type is <class 'str'>
# 50.75 is a Float Value and data type is <class 'float'>
# 2 is a integer Value and data type is <class 'int'>
# True is a boolean Value and data type is <class 'bool'>

# %% [markdown]
# **Q3. Arithmetic Operations**
#
# Create two number variables, calculate their: Addition
# • Subtraction
# • Multiplication
# • Division
# • Modulus
# • Power

# %%
A=10
B=3

print(f'Addition:       A+B={A+B}')

print(f'Subtraction:    A-B={A-B}')

print(f'Multiplication: A*B={A*B}')

print(f'Division:       A/B={A/B}')

print(f'Modulus:        A%B={A%B}')

print(f'power:          A**B={A**B}')
# Out:
# Addition:       A+B=13
# Subtraction:    A-B=7
# Multiplication: A*B=30
# Division:       A/B=3.3333333333333335
# Modulus:        A%B=1
# power:          A**B=1000

# %% [markdown]
# **Q4. Student Marks Calculator**
#
# Store the marks of three subjects in separate variables. Calculate and print the total
# marks and average marks.

# %%
math_marks = 85
physics_marks = 92
bio_marks = 78

total=math_marks + physics_marks + bio_marks
average=total/3
print(f'Total marks is: {total}')
print(f'Average marks is: {average}')
# Out:
# Total marks is: 255
# Average marks is: 85.0

# %% [markdown]
# **Q5.  Shopping Bill**
#
# Create variables for the product price and quantity. Calculate and print the total bill.

# %%
egg=35
quantity=12

total_bill= egg*quantity

print(f"Price per egg: PKR:{egg}")
print(f"Quantity: {quantity}")
print(f"Total Bill: PKR:{total_bill}")
# Out:
# Price per egg: PKR:35
# Quantity: 12
# Total Bill: PKR:420

# %% [markdown]
# **Q6.  Rectangle Area**
#
# Create variables for the length and width of a rectangle. Calculate and print its area and
# perimeter.

# %%
length = 15
width = 8

perimeter = 2 * (length + width)
area=length*width

# Printing the result
print(f"Length: {length} units")
print(f"Width: {width} units")
print(f"Area of Rectangle is: {area}")
print(f"Perimeter of the Rectangle is: {perimeter} ")
# Out:
# Length: 15 units
# Width: 8 units
# Area of Rectangle is: 120
# Perimeter of the Rectangle is: 46

# %% [markdown]
# **Q7. Time Converter**
#
# Store 250 minutes in a variable. Calculate and print the number of hours and remaining
# minutes.

# %%
minutes=250
hrs=minutes//60
remaining_minutes=250%60
print(f'number of hrs in 250 mins is: {hrs}')
print(f'number of remaining minutes is: {remaining_minutes}')
# Out:
# number of hrs in 250 mins is: 4
# number of remaining minutes is: 10

# %% [markdown]
# **Q8. Student Eligibility**
#
# Create variables for marks and attendance.
#
# A student is eligible if:
#
# • Marks are greater than or equal to 50
#
# • Attendance is greater than or equal to 75
#
# Use logical operators to calculate and print whether the student is eligible.

# %%
marks=59
attendance=74
marks>=50 and attendance>=75

is_eligible = (marks >= 50) and (attendance >= 75)

print(f"Marks: {marks}, Attendance: {attendance}%")
print(f"student eligiblity: {is_eligible}")
# Out:
# Marks: 59, Attendance: 74%
# student eligiblity: False

# %% [markdown]
# **Q9. Logical Opertaors**
#
# Create two Boolean variables:

# %%
a = True 
b = False 

print(f"a and b : {a and b}")
print(f"a or b  : {a or b}")
print(f"not a   : {not a}")
print(f"not b   : {not b}")
# Out:
# a and b : False
# a or b  : True
# not a   : False
# not b   : True

# %% [markdown]
# **Final Problem**
#
# Student Report

# %%
student_name='Huzaifa Tariq'
age= 23
attendance=78

urdu_marks = 85
Eng_marks = 92
math_marks = 78

total_marks= urdu_marks+ Eng_marks+ math_marks
avg_marks= total_marks/3

print('Student info')
print(f'    Name: {student_name}')
print(f'    Age: {age}')
print(f'    Attendance: {attendance} %')

print(f'Total marks: {total_marks} ')
print(f'Avgerage marks is: {avg_marks} ')

is_eligible = (avg_marks >= 50) and (attendance >= 75)

print(f"Student eligiblity: {is_eligible}")
# Out:
# Student info
#     Name: Huzaifa Tariq
#     Age: 23
#     Attendance: 78 %
# Total marks: 255
# Avgerage marks is: 85.0
# Student eligiblity: True
